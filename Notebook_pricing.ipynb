# %% [markdown]
# # API POUR FAIRE LES TRUCS DE MORT DE PRIX ET DE DISPONIBILITE

# %% [markdown]
# ## API pour MOUSER

# %%
import time
import logging
import requests
import pandas as pd

logger = logging.getLogger(__name__)

# %%
from Pricing_lcsc import *

# ============================================================
# MOUSER (scraping, pas de clé) - prix EUR natif + stock
# ============================================================
 
result = get_lcsc_price_from_page("C4410",20)
result
# Out:
# LCSC - HTTP : 200
# {'reference_lcsc': 'C4410',
#  'quantite_demandee': 20,
#  'prix_unitaire_eur': 0.00801,
#  'prix_paliers_eur': [(50, 0.00801),
#   (500, 0.00628),
#   (1500, 0.0056),
#   (5000, 0.00499),
#   (25000, 0.00482),
#   (50000, 0.00465)],
#  'stock': 2252250,
#  'quantite_suffisante': True}

# %%
result["stock"]
# Out:
# 2252250

# %% [markdown]
# # MAJ LIBRARY

# %%
from Pricing import Update_Price_Stock

# %%
name = "lib/Liste des composants.xlsx"
nom_feuille = "Feuille 1"
Update_Price_Stock(name,nom_feuille)
# Out:
# LDL1117S33R C435835
# LCSC - HTTP : 200
# VL53L7CXV0GC C5270520
# LCSC - HTTP : 200
# 06035C105KAT2A C2182269
# LCSC - HTTP : 200
# PZ254R-12-10P C492433
# LCSC - HTTP : 200
# RC0402FR-0747KL C93943
# LCSC - HTTP : 200
# RC0402JR-072K2L C163447
# LCSC - HTTP : 200
# ARG05FTC5000 C2828857
# LCSC - HTTP : 200
# RC0402FR-07220RL C112291
# LCSC - HTTP : 200
# PM254-2-05-S-8.5 C3975150
# LCSC - HTTP : 200
# HC-1.25-5PLT C2845391
# LCSC - HTTP : 200
# HC-1.25-3PLT C2845389
# LCSC - HTTP : 200
# WS2812B-V6 C52917433
# LCSC - HTTP : 200
# HSMG-C190 C188729
# LCSC - HTTP : 200
# CC0402KRX5R5BB475 C541466
# LCSC - HTTP : 200
# CC0402KRX5R6BB104 C129131
# LCSC - HTTP : 200
# X32258MOB4SI C2682775
# LCSC - HTTP : 200
# CC0402JRNPO9BN120 C106201
# LCSC - HTTP : 200
# CL31B475KBHNNNE C51205
# LCSC - HTTP : 200
# AP63356DV-7 C2157973
# LCSC - HTTP : 200
# TB67H450FNG_EL C545417
# LCSC - HTTP : 200
# ICM-42688-P C54308212
# LCSC - HTTP : 200
# HSMF-C165 C188726
# LCSC - HTTP : 200
# ...
